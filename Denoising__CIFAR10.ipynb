# %% [markdown]
# <a href="https://colab.research.google.com/github/pd1298/Denoising__CIFAR10/blob/master/Denoising__CIFAR10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing Dependencies
import numpy as np
import matplotlib.pyplot as plt 
from keras.layers import Conv2D, Input, Dense, Dropout, MaxPool2D, UpSampling2D
from keras.models import Model
from keras.datasets import cifar10

# %matplotlib inline

# %%
#Loading of CIFAR 10 Dataset

(cifar_train, _), (cifar_test, _) = cifar10.load_data()

size = 32
channel = 3
# scaling input data
cifar_train = cifar_train / 255
cifar_test = cifar_test / 255

# %%
#Adding noise to the cifar10 dataset with mean = 0, std = 0.3
noise = 0.3
cifar_train_noise = cifar_train + noise * np.random.normal(0, 0.3, size=cifar_train.shape) 
cifar_test_noise = cifar_test + noise * np.random.normal(0, 0.3, size=cifar_test.shape)

cifar_train_noise = np.clip(cifar_train_noise, 0, 1)
cifar_test_noise = np.clip(cifar_test_noise, 0, 1)

# %%
#Vizualization of training dataset with 

rows = 2 # number of rows in fig
cols = 6 # number of columns in fig

f = plt.figure(figsize=(2*cols,2*rows*2)) # defining a figure 

for i in range(rows):
    for j in range(cols): 
        f.add_subplot(rows*2,cols, (2*i*cols)+(j+1)) # adding sub plot to figure on each iteration
        plt.imshow(cifar_train_noise[i*cols + j]) 
        plt.axis("off")
        
    for j in range(cols): 
        f.add_subplot(rows*2,cols,((2*i+1)*cols)+(j+1)) # adding sub plot to figure on each iteration
        plt.imshow(cifar_train[i*cols + j]) 
        plt.axis("off")
        
f.suptitle("Sample From Training Data",fontsize=18)
plt.savefig("Cifar-train.png")

plt.show()

# %%
#Import
from keras.layers import Conv2DTranspose, BatchNormalization, add, LeakyReLU
from keras.optimizers import Adam

# %%
# Encoder 
inputs = Input(shape=(size,size,channel))

x = Conv2D(32, 3, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)
x = MaxPool2D()(x)
x = Dropout(0.25)(x)
skip = Conv2D(32, 3, padding='same')(x) # skip connection for decoder
x = LeakyReLU()(skip)
x = BatchNormalization()(x)
x = MaxPool2D()(x)
x = Dropout(0.25)(x)
x = Conv2D(64, 3, activation='relu', padding='same')(x)
x = BatchNormalization()(x)
encoded = MaxPool2D()(x)

# Decoder
x = Conv2DTranspose(64, 3,activation='relu',strides=(2,2), padding='same')(encoded)
x = BatchNormalization()(x)
x = Dropout(0.25)(x)
x = Conv2DTranspose(32, 3, activation='relu',strides=(2,2), padding='same')(x)
x = BatchNormalization()(x)
x = Dropout(0.25)(x)
x = Conv2DTranspose(32, 3, padding='same')(x)
x = add([x,skip]) # adding skip connection
x = LeakyReLU()(x)
x = BatchNormalization()(x)
decoded = Conv2DTranspose(3, 3, activation='sigmoid',strides=(2,2), padding='same')(x)

autoencoder = Model(inputs, decoded)
autoencoder.compile(optimizer=Adam(lr=0.001), loss='binary_crossentropy')
autoencoder.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   896         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 32)   0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 32)   9248        dropout_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 16, 16, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 32)   128         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 8, 8, 32)     0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 8, 8, 32)     0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 64)     18496       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 64)     256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 4, 4, 64)     0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 8, 8, 64)     36928       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 64)     256         conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 8, 8, 64)     0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 16, 16, 32)   18464       dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 32)   128         conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 16, 16, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 16, 16, 32)   9248        dropout_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 32)   0           conv2d_transpose_7[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 16, 16, 32)   0           add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 32)   128         leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 32, 32, 3)    867         batch_normalization_12[0][0]
# ==================================================================================================
# Total params: 95,171
# Trainable params: 94,659
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
# Training
epochs = 25
batch_size = 256

history = autoencoder.fit(cifar_train_noise,
                cifar_train,
                epochs=epochs,
                batch_size=batch_size,
                shuffle=True,
                validation_data=(cifar_test_noise, cifar_test)
               )
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 18s 363us/step - loss: 0.5751 - val_loss: 0.6172
# Epoch 2/25
# 50000/50000 [==============================] - 17s 334us/step - loss: 0.5586 - val_loss: 0.5786
# Epoch 3/25
# 50000/50000 [==============================] - 17s 335us/step - loss: 0.5570 - val_loss: 0.5604
# Epoch 4/25
# 50000/50000 [==============================] - 17s 334us/step - loss: 0.5561 - val_loss: 0.5576
# Epoch 5/25
# 50000/50000 [==============================] - 17s 333us/step - loss: 0.5556 - val_loss: 0.5549
# Epoch 6/25
# 50000/50000 [==============================] - 17s 334us/step - loss: 0.5553 - val_loss: 0.5554
# Epoch 7/25
# 50000/50000 [==============================] - 17s 333us/step - loss: 0.5550 - val_loss: 0.5557
# Epoch 8/25
# 50000/50000 [==============================] - 17s 334us/step - loss: 0.5548 - val_loss: 0.5549
# Epoch 9/25
# 50000/50000 [==============================] - 17s 333us/step - loss: 0.5547 - val_loss: 0.5538
# Epoch 10/25
# 50000/50000 [==============================] - 17s 334us/step - loss: 0.5546 - val_loss: 0.5543
# Epoch 11/25
# 50000/50000 [==============================] - 17s 333us/step - loss: 0.5544 - val_loss: 0.5545
# Epoch 12/25
# 50000/50000 [==============================] - 17s 333us/step - loss: 0.5544 - val_loss: 0.5548
# Epoch 13/25
# 50000/50000 [==============================] - 17s 333us/step - loss: 0.5543 - val_loss: 0.5547
# Epoch 14/25
# 50000/50000 [==============================] - 17s 334us/step - loss: 0.5542 - val_loss: 0.5536
# Epoch 15/25
# 50000/50000 [==============================] - 17s 333us/step - loss: 0.5542 - val_loss: 0.5533
# Epoch 16/25
# 50000/50000 [==============================] - 17s 332us/step - loss: 0.5541 - val_loss: 0.5533
# Epoch 17/25
# 50000/50000 [==============================] - 17s 342us/step - loss: 0.5540 - val_loss: 0.5540
# Epoch 18/25
# 50000/50000 [==============================] - 17s 338us/step - loss: 0.5540 - val_loss: 0.5536
# Epoch 19/25
# 50000/50000 [==============================] - 17s 339us/step - loss: 0.5539 - val_loss: 0.5533
# Epoch 20/25
# 50000/50000 [==============================] - 17s 341us/step - loss: 0.5539 - val_loss: 0.5533
# Epoch 21/25
# 50000/50000 [==============================] - 17s 339us/step - loss: 0.5539 - val_loss: 0.5531
# Epoch 22/25
# 50000/50000 [==============================] - 17s 337us/step - loss: 0.5539 - val_loss: 0.5549
# Epoch 23/25
# 50000/50000 [==============================] - 17s 336us/step - loss: 0.5539 - val_loss: 0.5540
# Epoch 24/25
# 50000/50000 [==============================] - 17s 338us/step - loss: 0.5538 - val_loss: 0.5531
# Epoch 25/25
# 50000/50000 [==============================] - 17s 337us/step - loss: 0.5538 - val_loss: 0.5533

# %%
# Defining Figure
f = plt.figure(figsize=(10,7))
f.add_subplot()

#Adding Subplot
plt.plot(history.epoch, history.history['loss'], label = "loss") # Loss curve for training set
plt.plot(history.epoch, history.history['val_loss'], label = "val_loss") # Loss curve for validation set

plt.title("Loss Curve",fontsize=18)
plt.xlabel("Epochs",fontsize=15)
plt.ylabel("Loss",fontsize=15)
plt.grid(alpha=0.3)
plt.legend()
plt.savefig("Loss_curve_cifar10.png")
plt.show()

# %%
# Select few random test images
num_imgs = 48
rand = np.random.randint(1, cifar_test_noise.shape[0]-48) 

cifar_test_images = cifar_test_noise[rand:rand+num_imgs] # slicing
cifar_test_desoided = autoencoder.predict(cifar_test_images) # predict

# %%
# Visualize test images with their denoised images

rows = 4 # number of rows in figure
cols = 12 # number of colums in figure
cell_size = 1.5
f = plt.figure(figsize=(cell_size*cols,cell_size*rows*2)) # defining a fig
f.tight_layout()
for i in range(rows):
    for j in range(cols): 
        f.add_subplot(rows*2,cols, (2*i*cols)+(j+1)) # adding sub plot to fig on each iteration
        plt.imshow(cifar_test_images[i*cols + j]) 
        plt.axis("off")
        
    for j in range(cols): 
        f.add_subplot(rows*2,cols,((2*i+1)*cols)+(j+1)) # adding sub plot to fig on each iteration
        plt.imshow(cifar_test_desoided[i*cols + j]) 
        plt.axis("off")

f.suptitle("Results",fontsize=18)
plt.savefig("test_results_cifar10.png")

plt.show()
